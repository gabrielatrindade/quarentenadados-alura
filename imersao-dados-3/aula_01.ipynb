# %% [markdown]
# # Aula 01

# %%
import pandas as pd

# %%
url = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

df = pd.read_csv(url, compression='zip')
df
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
df.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
df.shape
# Out:
# (23814, 877)

# %%
df['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
df['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
df['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
df['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
df['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
df['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
df['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# ### Desafios
#
# - Desafio 01: Investigar por que a classe tratamento é tão desbalanceada.
#
# - Desafio 02: Pesquisar como mostrar as 5 últimas linhas do dataframe.
#
# - Desafio 03: Calcule a proporção das classes tratamento através do pandas.
#
# - Desafio 04: Quantos tipos de drogas foram investigados?

# %%
df['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
df['dose'].value_counts(normalize=True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# ### Solução desafio 3

# %%
# desafio 3

df['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ---

# %%
df['tratamento'].value_counts().plot.pie()

# %%
df['tempo'].value_counts().plot.pie()

# %%
df['tempo'].value_counts().plot.bar()

# %%
df_g0_greater_than_0 = df[df['g-0'] > 0]

df_g0_greater_than_0.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 6  id_001bd861f  com_droga     24   D2  746ca1f5a  2.0440  1.7000 -1.5390
# 7  id_0020d0484  com_droga     48   D1  8b87a7a83  0.2711  0.5133 -0.1327
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 6  5.9440 -2.1670  ...  0.1855  1.1720  0.8325  0.6486  0.8090  1.5880
# 7  2.5950  0.6980  ...  0.3230 -0.4140  0.2532  0.0513  0.8600  1.4250
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
df.shape
# Out:
# (23814, 877)

# %% [markdown]
# ### Mais desafios
#
# - Desafio 05: Procure na documentação o método 'query' do pandas
#
# - Desafio 06: Deixar os gráficos com título, label - usar matplotlib.pyplot
#
# - Desafio 07: Renomear as colunas tirando o hífen
#
# - Desafio 08: Resumo do que você aprendeu com os dados
#
# ---
#
# ## Resolução desafios aula 01
#
# ### Desafio 01: Investigar por que a classe tratamento é tão desbalanceada.
# --
#
# ### Desafio 02: Pesquisar como mostrar as 5 últimas linhas do dataframe.

# %%
df.tail()
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 23809 -0.1112 -0.5080 -0.4713  ...  0.1969  0.0262 -0.8121  0.3434  0.5372
# 23810 -0.3743  0.9905 -0.7178  ...  0.4286  0.4426  0.0423 -0.3195 -0.8086
# 23811  0.3109 -0.7389  0.5505  ...  0.5409  0.3755  0.7343  0.2807  0.4116
# 23812  0.4392  0.2044  0.8531  ... -0.1105  0.4258 -0.2012  0.1506  1.5230
# 23813 -0.1361  0.7952 -0.3611  ... -3.3890 -1.7450 -6.6300 -4.0950 -7.3860
#
#          c-95    c-96    c-97    c-98    c-99
# ...

# %% [markdown]
# ### Desafio 03: Calcule a proporção das classes tratamento através do pandas.
# Feito durante a aula.
#
# ### Desafio 04: Quantos tipos de drogas foram investigados?

# %%
df['droga'].nunique()
# Out:
# 3289

# %% [markdown]
# ### Desafio 05: Procure na documentação o método 'query' do pandas
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
df_g0_greater_than_0_v2 = df.query('`g-0` > 0')

df_g0_greater_than_0_v2.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 6  id_001bd861f  com_droga     24   D2  746ca1f5a  2.0440  1.7000 -1.5390
# 7  id_0020d0484  com_droga     48   D1  8b87a7a83  0.2711  0.5133 -0.1327
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 6  5.9440 -2.1670  ...  0.1855  1.1720  0.8325  0.6486  0.8090  1.5880
# 7  2.5950  0.6980  ...  0.3230 -0.4140  0.2532  0.0513  0.8600  1.4250
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %% [markdown]
# Nota: O acento crase para a coluna só foi necessário devido ao hífen. O método query não permite alguns caracteres na string, gerando erro. O hífen é uma delas. Esse problema foi resolvido usando o acento crase.
# Para queries nas colunas como `id`, `tratamento`, `tempo`, `dose` ou `droga`, o uso da crase não seria necessário, pois não há caracteres não aceitos.
#
#
# Agora vamos verificar se o resultado da busca com o uso da máscara - True ou False - foi o mesmo resultado com o uso do método `query`.

# %%
# (df_g0_greater_than_0_v2 == df_g0_greater_than_0).any(1)
# pd.concat([df_g0_greater_than_0_v2, df_g0_greater_than_0]).drop_duplicates(keep=False)

df_g0_greater_than_0_v2.equals(df_g0_greater_than_0)
# Out:
# True

# %% [markdown]
# ### Desafio 06: Deixar os gráficos com título, label - usar matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(9,5))

df['tempo'].value_counts().plot.bar()

plt.title('Distribuição de experimentos por tempo', fontsize=18, pad=25)
plt.ylabel('Qnt de experimentos', fontsize=16)
plt.xlabel('Tempo do experimento', fontsize=16)

plt.show()

# %% [markdown]
# ### Desafio 07: Renomear as colunas tirando o hífen

# %%
df.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g-0', 'g-1', 'g-2',
#        'g-3', 'g-4',
#        ...
#        'c-90', 'c-91', 'c-92', 'c-93', 'c-94', 'c-95', 'c-96', 'c-97', 'c-98',
#        'c-99'],
#       dtype='object', length=877)

# %%
new_column_names = []

for column in df.columns:
    new_name = column.replace('-', '')
    new_column_names.append(new_name)
    
new_column_names[:10]
# Out:
# ['id', 'tratamento', 'tempo', 'dose', 'droga', 'g0', 'g1', 'g2', 'g3', 'g4']

# %% [markdown]
# - Outra maneira: Usando list comprehension:

# %%
new_column_names = [column.replace('-', '') for column in df.columns]

new_column_names[:10]
# Out:
# ['id', 'tratamento', 'tempo', 'dose', 'droga', 'g0', 'g1', 'g2', 'g3', 'g4']

# %% [markdown]
# - Mudando o nome das colunas

# %%
df.columns = new_column_names

# %%
df.head()
# Out:
#              id tratamento  tempo dose      droga      g0      g1      g2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#        g3      g4  ...     c90     c91     c92     c93     c94     c95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#       c96     c97     c98     c99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %% [markdown]
# ### Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# Só por curiosidade, cada linha é de fato um único experimento?

# %%
df['id'].nunique()
# Out:
# 23814

# %%
df['droga'].nunique()
# Out:
# 3289

# %% [markdown]
# - O conjunto de dados possui 877 colunas e 23814 linhas.
# - Cada linha representa um experimento com id único.
# - O tempo dos experimentos variam entre 24, 48 e 72 horas.
# - O tratamento é feito com droga ou com controle.
# - Existem 3289 tipos de drogas utilizadas.
# - Existem 2 tipos de dose: D1 e D2.
# - A distribuição de tratamento com droga e com controle é desbalanceada, sendo 92% dos experimentos com droga e 0.8% com controle.
